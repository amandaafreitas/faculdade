# %% [markdown]
# <a href="https://colab.research.google.com/github/amandaafreitas/faculdade/blob/main/projetoPhyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1**. **Importar os pacotes “pandas”, “matplotlib” e “seaborn”.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# **2. Apresente um descrito do repositório de dados**

# %%
data = pd.read_csv("segmentation.data", sep=",",skiprows = 2)
data.describe()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count           210.000000           210.000000               210.0
# mean            124.647619           122.757143                 9.0
# std              74.104024            58.139686                 0.0
# min               1.000000            11.000000                 9.0
# 25%              60.500000            81.500000                 9.0
# 50%             123.500000           121.500000                 9.0
# 75%             189.750000           174.500000                 9.0
# max             252.000000           250.000000                 9.0
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  \
# count            210.000000            210.000000  210.000000  210.000000
# mean               0.008466              0.006349    1.925132    5.719529
# std                0.029549              0.030077    3.158211   43.495942
# ...

# %% [markdown]
# UC Irvine (https://uci.edu) Machine Learning Repository
# Title: Image Segmentation data
# --- Creators: Vision Group, University of Massachusetts
# ---Donor: Vision Group (Carla Brodley, brodley@cs.umass.edu)
# --- Date:November,1990
# 'http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data'

# %% [markdown]
# **3. Importe os dados do repositório do item 2 em um Dataframe.**

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
# ...                        ...                  ...                 ...
# GRASS                     36.0                243.0                   9
# GRASS                    186.0                218.0                   9
# GRASS                    197.0                236.0                   9
# GRASS                    208.0                240.0                   9
# GRASS                    223.0                185.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# ...

# %% [markdown]
# **4. Apresente os 5 primeiros registros do Dataframe do item 3.**

# %%
df.head()
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# BRICKFACE                   0.0                   0.0    0.277778  0.062963
# BRICKFACE                   0.0                   0.0    0.333333  0.266667
# BRICKFACE                   0.0                   0.0    0.277778  0.107407
# BRICKFACE                   0.0                   0.0    0.500000  0.166667
# BRICKFACE                   0.0                   0.0    0.722222  0.374074
#
# ...

# %% [markdown]
# **5. Apresente as colunas do Dataframe do item 3.**

# %%
df.columns.tolist()
# Out:
# ['REGION-CENTROID-COL',
#  'REGION-CENTROID-ROW',
#  'REGION-PIXEL-COUNT',
#  'SHORT-LINE-DENSITY-5',
#  'SHORT-LINE-DENSITY-2',
#  'VEDGE-MEAN',
#  'VEDGE-SD',
#  'HEDGE-MEAN',
#  'HEDGE-SD',
#  'INTENSITY-MEAN',
#  'RAWRED-MEAN',
#  'RAWBLUE-MEAN',
#  'RAWGREEN-MEAN',
#  'EXRED-MEAN',
#  'EXBLUE-MEAN',
#  'EXGREEN-MEAN',
#  'VALUE-MEAN',
#  'SATURATION-MEAN',
#  'HUE-MEAN']

# %% [markdown]
# **6. Apresente os tipos de dados das colunas do Dataframe do item 3.**

# %%
df.dtypes
# Out:
# REGION-CENTROID-COL     float64
# REGION-CENTROID-ROW     float64
# REGION-PIXEL-COUNT        int64
# SHORT-LINE-DENSITY-5    float64
# SHORT-LINE-DENSITY-2    float64
# VEDGE-MEAN              float64
# VEDGE-SD                float64
# HEDGE-MEAN              float64
# HEDGE-SD                float64
# INTENSITY-MEAN          float64
# RAWRED-MEAN             float64
# RAWBLUE-MEAN            float64
# RAWGREEN-MEAN           float64
# EXRED-MEAN              float64
# EXBLUE-MEAN             float64
# EXGREEN-MEAN            float64
# VALUE-MEAN              float64
# SATURATION-MEAN         float64
# HUE-MEAN                float64
# dtype: object

# %% [markdown]
# **7. Apresente uma análise exploratória dos dados do Dataframe do item 3**

# %%
df.describe()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count           210.000000           210.000000               210.0
# mean            124.647619           122.757143                 9.0
# std              74.104024            58.139686                 0.0
# min               1.000000            11.000000                 9.0
# 25%              60.500000            81.500000                 9.0
# 50%             123.500000           121.500000                 9.0
# 75%             189.750000           174.500000                 9.0
# max             252.000000           250.000000                 9.0
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  \
# count            210.000000            210.000000  210.000000  210.000000
# mean               0.008466              0.006349    1.925132    5.719529
# std                0.029549              0.030077    3.158211   43.495942
# ...

# %% [markdown]
# **8. Selecione uma das características do Dataframe e exclua os dados NA.**

# %%
intensity = data[["INTENSITY-MEAN"]].dropna()
display(intensity)
# Out:
#            INTENSITY-MEAN
# BRICKFACE        6.185185
# BRICKFACE        6.666666
# BRICKFACE        6.111111
# BRICKFACE        5.851852
# BRICKFACE        6.037037
# ...                   ...
# GRASS           13.333333
# GRASS           13.703704
# GRASS           16.074074
# GRASS           14.148149
# GRASS           12.962963
#
# [210 rows x 1 columns]

# %% [markdown]
# **9. Apresente o histograma dos dados do item 8.**

# %%
intensity.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5af9bf7e10>]],
#       dtype=object)

# %% [markdown]
# **10. Apresente uma conclusão do seu trabalho.**
#
# Foram utilizadas as bibliotecas pandas para manipulação e análise de dados e seaborn e matplotlib para criaçao de gráficos.
